# %%
from src.visualization.visualiztion_utils import compare_models_bar

tasks = ['singing_music', 'speech_music', 'move_rest']
classifier_list = ['Logistic_regression', 'Naive_bayes', 'RandomForest', 'SVM', 'XGBoost']
path_result = 'F:/Thesis Master/Single_patient_paper/'

compare_models_bar(tasks, classifier_list, path_result)

# %%
from src.visualization.visualiztion_utils import compare_models_box

tasks = ['singing_music', 'speech_music', 'move_rest']
classifier_list = ['Logistic_regression', 'Naive_bayes', 'RandomForest', 'SVM', 'XGBoost']
path_result = 'F:/Thesis Master/Single_patient_paper/'

compare_models_box(tasks, classifier_list, path_result)
